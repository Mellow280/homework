# %% [markdown]
# HW

# %%
# person info

name = 'Sydney LaMelle'.upper()
age = 20
grade = float(90.5)
is_student: bool= (True) 
favorite_color = 'teal'

print(f'name: {name}')
# Out:
# name: SYDNEY LAMELLE

# %%
add = int(age) + int(grade)
add = int(20) + int(90.5)
print(f'age: {age}' )
print(f'grade: {grade}' )

print(f'add: {add}')
# Out:
# age: 20
# grade: 90.5
# add: 110

# %%
# dictionary

dict = {person}
