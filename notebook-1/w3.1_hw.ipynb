# %% [markdown]
# HW

# %%
# person info

name = 'Sydney LaMelle'.upper()
age = 20
grade = float(90.5)
is_student: bool= (True) 
favorite_color = 'teal'

print(f'name: {name}')
# Out:
# name: SYDNEY LAMELLE

# %%
add = int(age) + int(grade)

print(f'age: {age}')
print(f'grade: {grade}')
print(f'add: {add}')
# Out:
#   Cell In[3], line 1
#     add int(20) + int(grade)
#         ^
# SyntaxError: invalid syntax
